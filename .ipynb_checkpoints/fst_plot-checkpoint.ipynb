# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("NW_022145594.1_12670717_16440127_fst.weir.fst", sep="\t")
df
# Out:
#                   CHROM       POS  WEIR_AND_COCKERHAM_FST
# 0        NW_022145594.1      5743                     NaN
# 1        NW_022145594.1      5749               -0.004901
# 2        NW_022145594.1      5753                0.034949
# 3        NW_022145594.1      5787               -0.013706
# 4        NW_022145594.1      5822               -0.013706
# ...                 ...       ...                     ...
# 3999250  NW_022145594.1  53064844               -0.010691
# 3999251  NW_022145594.1  53075543               -0.004512
# 3999252  NW_022145594.1  53092813                0.004580
# 3999253  NW_022145594.1  53099165               -0.017406
# 3999254  NW_022145594.1  53099292               -0.014954
#
# [3999255 rows x 3 columns]

# %%
fig, ax1 = plt.subplots(figsize=(16, 8))
plt.plot(df["POS"], df["WEIR_AND_COCKERHAM_FST"], ".")

#plt.xlim(12_290_000, 12_600_000)
plt.axvline(12_534_000, color="red")
plt.axvline(12_536_000, color="red")

plt.ylabel("Fst, homo1 vs homo2")
plt.xlabel("Genomic position")
#plt.savefig("fst.jpeg")
# Out:
# Text(0.5, 0, 'Genomic position')
